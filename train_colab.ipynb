# %% [markdown]
# # Train Your Voice Model on Colab GPU 🚀
# 1. In the menu above, go to **Runtime > Change runtime type** and select **T4 GPU**.
# 2. On your PC, open your `voicemodel` directory, select the `data`, `src`, `requirements.txt`, and `TODO.md` files, and add them to an archive named `voicemodel.zip` (IMPORTANT: do **not** include the `venv` or `.git` folders! They take up way too much space).
# 3. Upload the `voicemodel.zip` file to this Google Colab by clicking the Folder icon on the left-hand menu and dragging it in.
# 4. Run the cells below one by one!

# %%
# !unzip -o -q voicemodel.zip -d voicemodel

# %%
import os
os.chdir('voicemodel')

# %%
# !pip install -r requirements.txt
# !pip install accelerate tensorboard

# %%
# This will load your dataset and start fine-tuning the model.
# You should see it complete all 500 steps in about ~15 minutes on a T4 GPU!
# !python src/train.py

# %%
# Once training finishes, zip up the generated model folder so you can download it to your PC
# !zip -r trained_model.zip models/speecht5_finetuned_final

print("Done! Look in your files on the left for `voicemodel/trained_model.zip` and download it.")
